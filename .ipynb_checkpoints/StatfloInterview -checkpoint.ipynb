# %% [markdown]
# # Statflo Interview

# %% [markdown]
# At Quora, we deal with a lot of data. As the number of users on our site grows, so does the volume of content and the number of interactions that go on daily.
#
# We want to be able to determine various social and intellectual topics that are trending over time. However, we take privacy very seriously, and so we want to do this in a way that does not put any individual’s personal information at risk.
#
# Your task is to design and implement a trend analysis engine. This engine should be able to take as input a table of raw data and present an interface for trend analysis. You are free to design this interface and choose the data analysis features that you wish to support. It is important that the engine only exposes to the user data that does not have any personal identifiers and protects sensitive attributes from being revealed. We provide some links to resources about how to think about this in the Resources section.

# %% [markdown]
# Your engine should take as input a path to a comma-delimited text file. The first line will be the field names, and the second line will be the field type. The remaining rows will be the raw data.
#
# The table below lists the field types we want you to support. If you have ideas for other types, feel free to include support for them and provide us an input file for us to evaluate them.

# %%
import unicodecsv as csv
from faker import Factory 
from collections import defaultdict

#This was adapted from the following URL blogpost http://blog.districtdatalabs.com/a-practical-guide-to-anonymizing-datasets-with-python-faker
#This code will anomitize the dataset if desired

class ReadandAnonmitizeDataset():
    
    def anonymize_rows(rows):
        faker = Factory.create()
        names = defaultdict(faker.name)
        emails = defaultdict(faker.email)
        
        for row in rows:
            row['name'] = names[row['name']]
            row['email'] = emails[row['email']]
            yield row
    
    
    def anonymize(source, target):
        with open(source, 'rU') as f:
            with open(target, 'w') as o:
                reader = csv.DictReader(f)
                writer = csv.DictWriter(o, reader.fieldnames)
                for row in anonymize_rows(reader):
                    writer.writerow(row)

# %%
ReadandAnonmitizeDataset()

# %%
import pandas as pd
import ploty 

#This code will read in the file and plot interesting information 
def readfile():
    pd.read_csv('/Users/marconlaforet/Python_notebook_jupyter/Statflo_challenge/QuoraTrendAnalyzer_SampleData/airsampling.csv', header=int(1))
# Out:
#                       DATE MATRIX            SAMPLE NAME LOCATION  \
# 0      09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 1      09/18/2010 12:00 AM    Air   C05-20100917-0945-24      C05
# 2      09/18/2010 12:00 AM    Air   C05-20100917-0945-24      C05
# 3      09/18/2010 12:00 AM    Air   C05-20100917-0945-24      C05
# 4      09/18/2010 12:00 AM    Air   C05-20100917-0945-24      C05
# 5      09/18/2010 12:00 AM    Air   C05-20100917-0945-24      C05
# 6      09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 7      09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 8      09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 9      09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 10     09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 11     09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 12     09/18/2010 12:00 AM    Air  C05-20100917-0945-PUF      C05
# 13     09/17/2010 12:00 AM    Air             0092101-02     FAAL
# 14     09/17/2010 12:00 AM    Air             0092102-02     GPMS
# 15     09/17/2010 12:00 AM    Air             0092103-01     PEFL
# 16     09/17/2010 12:00 AM    Air             0092103-01     PEFL
# 17     09/17/2010 12:00 AM    Air             0092102-01     GPMS
# 18     09/17/2010 12:00 AM    Air             0092102-01     GPMS
# 19     09/17/2010 12:00 AM    Air             0092102-01     GPMS
# 20     09/17/2010 12:00 AM    Air             0092101-01     FAAL
# 21     09/17/2010 12:00 AM    Air             0092101-01     FAAL
# 22     09/17/2010 12:00 AM    Air             0092101-01     FAAL
# 23     09/17/2010 12:00 AM    Air             0092101-01     FAAL
# 24     09/17/2010 12:00 AM    Air             0092102-02     GPMS
# 25     09/17/2010 12:00 AM    Air             0092101-01     FAAL
# 26     09/17/2010 12:00 AM    Air             0092101-01     FAAL
# 27     09/17/2010 12:00 AM    Air             0092101-01     FAAL
#
# 10       Louisiana      50-32-8          Benzo[a]pyrene        NaN  ug/m3
# 11       Louisiana     193-39-5  Indeno[1 2 3-cd]pyrene        NaN  ug/m3
# 12       Louisiana      56-55-3       Benz[a]anthracene        NaN  ug/m3
# 13         Alabama  179601-23-1              m p-Xylene   2.270000  ug/m3
# 14     Mississippi  179601-23-1              m p-Xylene   1.390000  ug/m3
# 15         Florida     207-08-9    Benzo[k]fluoranthene        NaN  ug/m3
# 16         Florida     218-01-9                Chrysene   0.000112  ug/m3
# 17     Mississippi      91-20-3             Naphthalene   0.080000  ug/m3
# 18     Mississippi     193-39-5  Indeno[1 2 3-cd]pyrene        NaN  ug/m3
# 19     Mississippi      50-32-8          Benzo[a]pyrene        NaN  ug/m3
# 20         Alabama      56-55-3       Benz[a]anthracene        NaN  ug/m3
# 21         Alabama      50-32-8          Benzo[a]pyrene        NaN  ug/m3
# 22         Alabama     207-08-9    Benzo[k]fluoranthene        NaN  ug/m3
# 23         Alabama     218-01-9                Chrysene        NaN  ug/m3
# 24     Mississippi     100-41-4            Ethylbenzene   0.480000  ug/m3
# 25         Alabama      91-20-3             Naphthalene   0.170000  ug/m3
# 26         Alabama     193-39-5  Indeno[1 2 3-cd]pyrene        NaN  ug/m3
# 27         Alabama      53-70-3   Dibenz[a h]anthracene        NaN  ug/m3
# 28         Alabama     205-99-2    Benzo(b)fluoranthene        NaN  ug/m3
# 29         Florida      91-20-3             Naphthalene   0.070000  ug/m3
# ...            ...          ...                     ...        ...    ...
# 10216    Louisiana     108-88-3                 Toluene        NaN  ug/m3
# 10217    Louisiana  179601-23-1              m p-Xylene        NaN  ug/m3
# 10218    Louisiana      95-47-6                o-Xylene        NaN  ug/m3
# 10219    Louisiana     100-41-4            Ethylbenzene        NaN  ug/m3
# 10220    Louisiana      71-43-2                 Benzene        NaN  ug/m3
# 10221    Louisiana     100-41-4            Ethylbenzene        NaN  ug/m3
# 10222    Louisiana  179601-23-1              m p-Xylene   2.400000  ug/m3
# 10223    Louisiana      95-47-6                o-Xylene   0.880000  ug/m3
# 10224    Louisiana      71-43-2                 Benzene        NaN  ug/m3
# 10225    Louisiana     108-88-3                 Toluene   0.960000  ug/m3
# 10226    Louisiana      EDF-213                   PM2.5  12.170000  ug/m3
# 10227    Louisiana  179601-23-1              m p-Xylene        NaN  ug/m3
# 10228    Louisiana      95-47-6                o-Xylene        NaN  ug/m3
# 10229    Louisiana      71-43-2                 Benzene        NaN  ug/m3
# 10230    Louisiana     108-88-3                 Toluene        NaN  ug/m3
# 10231    Louisiana     100-41-4            Ethylbenzene        NaN  ug/m3
# 10232          NaN  179601-23-1              m p-Xylene        NaN  ug/m3
# 10233          NaN      95-47-6                o-Xylene        NaN  ug/m3
# 10234          NaN      EDF-213                   PM2.5  11.860000  ug/m3
# 10235          NaN      71-43-2                 Benzene        NaN  ug/m3
# 10236          NaN     100-41-4            Ethylbenzene        NaN  ug/m3
# 10231         0.660000                ug/m3    False        64    70091.0
# 10232         2.900000                ug/m3    False        13        NaN
# 10233         2.900000                ug/m3    False         2        NaN
# 10234         0.000000                  NaN     True        87        NaN
# 10235         2.100000                ug/m3    False        51        NaN
# 10236         2.900000                ug/m3    False        95        NaN
# 10237         2.500000                ug/m3    False        24        NaN
# 10238         0.000000                  NaN     True        90        NaN
# 10239         0.000000                  NaN     True         4    70041.0
# 10240         0.000000                  NaN     True        64    70091.0
# 10241         0.580000                ug/m3    False        54    70091.0
# 10242         0.500000                ug/m3    False        61    70091.0
# 10243         0.580000                ug/m3    False        95    70091.0
# 10244         0.430000                ug/m3    False        39    70091.0
# 10245         0.580000                ug/m3    False        42    70091.0
#
# [10246 rows x 14 columns]

# %%
pd.read_csv('/Users/marconlaforet/Python_notebook_jupyter/Statflo_challenge/SampleData/CleanedFiles/hospital.csv', header=int(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-42d6a605995b> in <module>()
# ----> 1 pd.read_csv('/Users/marconlaforet/Python_notebook_jupyter/Statflo_challenge/SampleData/CleanedFiles/hospital.csv', header=int(1))
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
whitehouse = pd.read_csv('/Users/marconlaforet/Python_notebook_jupyter/StatfloChallenge/SampleData/CleanedFiles/whitehouse.csv', header=int(1))

# %%
# Out:
# Running unit tests for pandas
# pandas version 0.18.1
# numpy version 1.11.0
# pandas is installed in /Users/marconlaforet/bin/anaconda/lib/python3.4/site-packages/pandas
# Python version 3.4.4 |Anaconda 2.3.0 (x86_64)| (default, Jan  9 2016, 17:30:09) [GCC 4.2.1 (Apple Inc. build 5577)]
# nose version 1.3.7
# /Users/marconlaforet/bin/anaconda/lib/python3.4/importlib/_bootstrap.py:321: FutureWarning: The pandas.rpy module is deprecated and will be removed in a future version. We refer to external packages like rpy2.
# See here for a guide on how to port your code to rpy2: http://pandas.pydata.org/pandas-docs/stable/r_interface.html
#   return f(*args, **kwds)
# .SS..SS..SS..SS..SS..SS..SS..SS..SSSSSSSSSSSSSS..SS..SS..SS.........SS..SS..SS..SS..SS..SS..SSSSSSSSSSSSSSSS................SS..SS..........................................................................................................................................................................S.........................................................S...............................S.......................................................................................................S...........................................S...............................S.......................................................................................................S..........................................................S................................................................................................S.....................................................S........SS......SS..........
# ----------------------------------------------------------------------
# Ran 899 tests in 70.378s
#
# OK (SKIP=82)
# <nose.result.TextTestResult run=899 errors=0 failures=0>

# %%
whitehouse.dtypes
# Out:
# ID                  object
# ID.1                object
# ID.2                object
# TIME                object
# TIME.1              object
# CONT               float64
# CAT/SENSITIVE       object
# CAT/SENSITIVE.1     object
# CAT                 object
# CAT.1              float64
# CAT/SENSITIVE.2     object
# CAT/SENSITIVE.3     object
# CAT.2               object
# TIME.2              object
# dtype: object

# %%
import pandas
from sklearn import preprocessing

# %%
whitehouse.apply(preprocessing.LabelEncoder().fit_transform)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-cb9c66e1d442> in <module>()
# ----> 1 whitehouse.apply(LabelEncoder().fit_transform)
#
# NameError: name 'LabelEncoder' is not defined
